# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 

# File to Load 
tripdata_data_to_load = "201908-citibike-tripdata.csv"

# Read the tripdata Data
tripdata_df = pd.read_csv(tripdata_data_to_load)

tripdata_df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 393  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
# 1                 627  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840
# 2                1132  2019-08-01 00:00:04.0480  2019-08-01 00:18:56.1650
# 3                1780  2019-08-01 00:00:04.1630  2019-08-01 00:29:44.7940
# 4                1517  2019-08-01 00:00:05.4580  2019-08-01 00:25:23.4550
# ...               ...                       ...                       ...
# 2344219           216  2019-08-31 23:59:46.2930  2019-09-01 00:03:23.0360
# 2344220           117  2019-08-31 23:59:47.7970  2019-09-01 00:01:45.7440
# 2344221          1614  2019-08-31 23:59:48.1560  2019-09-01 00:26:42.7760
# 2344222          1301  2019-08-31 23:59:58.3620  2019-09-01 00:21:39.7040
# 2344223           419  2019-08-31 23:59:59.4520  2019-09-01 00:06:59.0210
#
#          start station id              start station name  \
# ...

# %%
# 2. Check the datatypes of your columns. 
tripdata_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
tripdata_df['tripduration'] = pd.to_datetime(tripdata_df['tripduration'], unit = 's')

# %%
# 4. Check the datatypes of your columns. 
tripdata_df.dtypes
# Out:
# tripduration               datetime64[ns]
# starttime                          object
# stoptime                           object
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# dtype: object

# %%
# Confirm tripduration column 
tripdata_df.head()
# Out:
#          tripduration                 starttime                  stoptime  \
# 0 1970-01-01 00:06:33  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
# 1 1970-01-01 00:10:27  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840
# 2 1970-01-01 00:18:52  2019-08-01 00:00:04.0480  2019-08-01 00:18:56.1650
# 3 1970-01-01 00:29:40  2019-08-01 00:00:04.1630  2019-08-01 00:29:44.7940
# 4 1970-01-01 00:25:17  2019-08-01 00:00:05.4580  2019-08-01 00:25:23.4550
#
#    start station id              start station name  start station latitude  \
# 0             531.0          Forsyth St & Broome St               40.718939
# 1             274.0  Lafayette Ave & Fort Greene Pl               40.686919
# 2            2000.0        Front St & Washington St               40.702551
# 3             479.0                 9 Ave & W 45 St               40.760193
# 4            3312.0                 1 Ave & E 94 St               40.781721
#
# ...

# %%
# 5. Export the Dataframe as a new CSV file without the index.
tripdata_df.to_csv('new_201908-citibike-tripdata.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 # 5. Export the Dataframe as a new CSV file without the index.
# ----> 2 tripdata_df.to_csv('new_201908-citibike-tripdata.csv', index = False)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
# ...
